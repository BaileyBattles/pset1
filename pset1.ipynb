# %% [markdown]
# ## PSET1

# %%
#GLOBALS
L = 5
H = 6
gamma = 0.9
p_e = 0.01
epsilon = 0.01

# %% [markdown]
# ### Question 1a
# 1(a). Create (in code) your state space S = {s}. What is the size of the state space NS?
# ### Answer
# The size of NS = L * H

# %%
class StateSpace:
    """
    State is a H by L grid where a 0 represents an open space and a 1 represents an obstacle
    ObstacleList should be a list of tuples where each tuple is (row, col) of the obstacle
    """
    def __init__(self, L, H, obstacleList = []):
        self.numRows = H
        self.numCols = L
        self.stateSpace = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
        for obstacle in obstacleList:
            self.stateSpace[obstacle[0]][obstacle[1]] = -1
    
    def validPosition(self, row, col):
        if row < 0 or col < 0 or row >= self.numRows or col >= self.numCols:
            return False
        return True

# %% [markdown]
# ### Question 1(b)
# Create (in code) your action space A = {a}. What is the size of the action space NA?
# ### Answer
# The size of NA = 5.  The robot can either move up, down, left, right, or not do anything.
# In code I am going to setup the action space as a list of possible states that could be possible given a robot's position.
# I will also build a robot calss at this time.

# %%
class Action:
    def __init__(self, move):
        if move != 'left' and move != 'right' and move != 'up' and move != 'down' and move != 'none':
            print("MOVE MUST BE A VALID MOVE")
        self.move = move
        
class StateSpace:
    """
    State is a H by L grid where a 0 represents an open space and a 1 represents an obstacle
    ObstacleList should be a list of tuples where each tuple is (row, col) of the obstacle
    """
    def __init__(self, L, H, obstacleList = []):
        self.numRows = H
        self.numCols = L
        self.stateSpace = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
        for obstacle in obstacleList:
            self.stateSpace[obstacle[0]][obstacle[1]] = -1
    
    def validPosition(self, row, col):
        if row < 0 or col < 0 or row >= self.numRows or col >= self.numCols:
            return False
        return True
    def getMoves(self, row, col):
        moves = [(row, col)]
        if stateSpace.validPosition(row - 1, col):
            moves.append((row - 1, col))
        
        if stateSpace.validPosition(row + 1, col):
            moves.append((row + 1, col))
        
        if stateSpace.validPosition(row, col - 1):
            moves.append((row, col - 1))
        
        if stateSpace.validPosition(row, col + 1):
            moves.append((row, col + 1))
        return moves
    
    def nextIntendedPosition(self, row, col, action):
        if action.move == 'left':
            return (row, col - 1)
        elif action.move == 'right':
            return (row, col + 1)
        elif action.move == 'none':
            return (row, col)
        elif action.move == 'up':
            return (row - 1, col)
        elif action.move == 'down':
            return (row + 1, col)
        else:
            print("Not a valid move")

# %% [markdown]
# ### Question 1(c)
# Write a function that returns the probability psa(s') given inputs s, a, s0 (and global constant error probability pe). Assume for now that there are no obstacles.

# %%
class StateSpace:
    """
    State is a H by L grid where a 0 represents an open space and a 1 represents an obstacle
    ObstacleList should be a list of tuples where each tuple is (row, col) of the obstacle
    """
    def __init__(self, L, H, obstacleList = []):
        self.numRows = H
        self.numCols = L
        self.stateSpace = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
        for obstacle in obstacleList:
            self.stateSpace[obstacle[0]][obstacle[1]] = -1
    
    def validPosition(self, row, col):
        if row < 0 or col < 0 or row >= self.numRows or col >= self.numCols:
            return False
        return True
    def getMoves(self, row, col):
        moves = [(row, col)]
        if stateSpace.validPosition(row - 1, col):
            moves.append((row - 1, col))
        
        if stateSpace.validPosition(row + 1, col):
            moves.append((row + 1, col))
        
        if stateSpace.validPosition(row, col - 1):
            moves.append((row, col - 1))
        
        if stateSpace.validPosition(row, col + 1):
            moves.append((row, col + 1))
        return moves
    
    def nextIntendedPosition(self, row, col, action):
        if action.move == 'left':
            return (row, col - 1)
        elif action.move == 'right':
            return (row, col + 1)
        elif action.move == 'none':
            return (row, col)
        elif action.move == 'up':
            return (row - 1, col)
        elif action.move == 'down':
            return (row + 1, col)
        else:
            print("Not a valid move")
            
    def probabilityNewState(self, s, a, s0):
        if not stateSpace.validPosition(s[0], s[1]):
            return 0

        if (s[0], s[1]) not in stateSpace.getMoves(s0[0], s0[1]):
            return 0

        intendedRow, intendedCol = stateSpace.nextIntendedPosition(s0[0], s0[1], a)
        if s[0] == intendedRow and s[1] == intendedCol:
            if a.move == 'none':
                return 1.
            else:
                return 1. - p_e + p_e/4

        #If next state is a position robot was not intending to go
        elif s[0] == s0[0] and s[1] == s0[1]:
            return 0
        else:
            return p_e

# %% [markdown]
# ### Question 2(a), 2(b)
# 2(a). Update the state transition function from 1(c) to incorporate the displayed obstacles.
#    I have updated the validPosition function to take into account obstacles
#
# 2(b). Write a function that returns the reward r(s) given input s.
#     I added the getReward function to return a reward at a given state

# %%
class StateSpace:
    """
    State is a H by L grid where a 0 represents an open space and a 1 represents an obstacle
    ObstacleList should be a list of tuples where each tuple is (row, col) of the obstacle
    RewardList should be a three tuple (row, col, rewardValue)
    """
    def __init__(self, L, H, obstacleList = [], rewardList = []):
        self.numRows = H
        self.numCols = L
        self.stateSpace = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
        for obstacle in obstacleList:
            self.stateSpace[obstacle[0]][obstacle[1]] = -1
        self.rewardMap = {}
        for reward in rewardList:
            self.rewardMap[(reward[0], reward[1])] = reward[2]
    
    def validPosition(self, row, col):
        if row < 0 or col < 0 or row >= self.numRows or col >= self.numCols:
            return False
        #2a
        if self.stateSpace[row][col] == -1:
            return False
        return True
    
    #2b
    def getReward(self, row, col):
        if (row, col) in self.rewardMap:
            return self.rewardMap[(row, col)]
        else:
            return 0
    
    def getMoves(self, row, col):
        moves = [(row, col)]
        if stateSpace.validPosition(row - 1, col):
            moves.append((row - 1, col))
        
        if stateSpace.validPosition(row + 1, col):
            moves.append((row + 1, col))
        
        if stateSpace.validPosition(row, col - 1):
            moves.append((row, col - 1))
        
        if stateSpace.validPosition(row, col + 1):
            moves.append((row, col + 1))
        return moves
    
    def getActions(self, row, col):
        actions = [Action('none')]
        if stateSpace.validPosition(row - 1, col):
            actions.append(Action('up'))
        
        if stateSpace.validPosition(row + 1, col):
            actions.append(Action('down'))
        
        if stateSpace.validPosition(row, col - 1):
            actions.append(Action('left'))
        
        if stateSpace.validPosition(row, col + 1):
            actions.append(Action('right'))
        return actions
    
    def nextIntendedPosition(self, row, col, action):
        if action.move == 'left':
            return (row, col - 1)
        elif action.move == 'right':
            return (row, col + 1)
        elif action.move == 'none':
            return (row, col)
        elif action.move == 'up':
            return (row - 1, col)
        elif action.move == 'down':
            return (row + 1, col)
        else:
            print("Not a valid move")
    
    def probabilityNewState(self, s, a, s0):
        if not stateSpace.validPosition(s[0], s[1]):
            return 0

        if (s[0], s[1]) not in stateSpace.getMoves(s0[0], s0[1]):
            return 0

        intendedRow, intendedCol = stateSpace.nextIntendedPosition(s0[0], s0[1], a)
        if s[0] == intendedRow and s[1] == intendedCol:
            if a.move == 'none':
                return 1.
            else:
                return 1. - p_e + p_e/4

        #If next state is a position robot was not intending to go
        elif s[0] == s0[0] and s[1] == s0[1]:
            return 0
        else:
            return p_e

# %% [markdown]
# ### Question 3(a)
# Create and populate a matrix/array that contains the actions {a = π0(s)}, π0(s) ∈ A prescribed by the initial
# policy π0 when indexed by state s

# %%
pi_matrix = [[Action('left') for x in range(L)] for x in range(H)]

# %% [markdown]
# ### Question 3(b)
# Write a function to display any input policy pi, and use it to display pi_0

# %%
class Policy:
    def __init__(self, policyMatrix):
        # PolicyFunction should take two arguments, stateSpace and state
        self.policyMatrix = policyMatrix
    
    def displayPolicy(self, stateSpace):
        display = [["" for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)]
        for row in range(stateSpace.numRows):
            for col in range(stateSpace.numCols):
                display[row][col] = self.policyMatrix[row][col].move
        for row in display:
            print(row)

# %%
alwaysLeft = Policy([[Action('left') for x in range(L)] for x in range(H)])
stateSpace = StateSpace(L, H)
alwaysLeft.displayPolicy(stateSpace)
# Out:
# ['left', 'left', 'left', 'left', 'left']
# ['left', 'left', 'left', 'left', 'left']
# ['left', 'left', 'left', 'left', 'left']
# ['left', 'left', 'left', 'left', 'left']
# ['left', 'left', 'left', 'left', 'left']
# ['left', 'left', 'left', 'left', 'left']

# %% [markdown]
# ### Question 3(c)
# Write a function to compute the policy evaluation of a policy π. That is, this function should return the
# matrix/array of values {v = V(s)}, V(s) ∈ R when indexed by state s. The input will be a matrix/array
# storing π as above (and will use global constant discount factor γ).

# %%
class StateSpace:
    """
    State is a H by L grid where a 0 represents an open space and a 1 represents an obstacle
    ObstacleList should be a list of tuples where each tuple is (row, col) of the obstacle
    RewardList should be a three tuple (row, col, rewardValue)
    """
    def __init__(self, L, H, obstacleList = [], rewardList = []):
        self.numRows = H
        self.numCols = L
        self.stateSpace = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
        for obstacle in obstacleList:
            self.stateSpace[obstacle[0]][obstacle[1]] = -1
        self.rewardMap = {}
        for reward in rewardList:
            self.rewardMap[(reward[0], reward[1])] = reward[2]
    def validPosition(self, row, col):
        if row < 0 or col < 0 or row >= self.numRows or col >= self.numCols:
            return False
        #2a
        if self.stateSpace[row][col] == -1:
            return False
        return True
    
    #2b
    def getReward(self, row, col):
        if (row, col) in self.rewardMap:
            return self.rewardMap[(row, col)]
        else:
            return 0
    
    def getMoves(self, row, col):
        moves = [(row, col)]
        if stateSpace.validPosition(row - 1, col):
            moves.append((row - 1, col))
        
        if stateSpace.validPosition(row + 1, col):
            moves.append((row + 1, col))
        
        if stateSpace.validPosition(row, col - 1):
            moves.append((row, col - 1))
        
        if stateSpace.validPosition(row, col + 1):
            moves.append((row, col + 1))
        return moves
    
    def getActions(self, row, col):
        actions = [Action('none')]
        if stateSpace.validPosition(row - 1, col):
            actions.append(Action('up'))
        
        if stateSpace.validPosition(row + 1, col):
            actions.append(Action('down'))
        
        if stateSpace.validPosition(row, col - 1):
            actions.append(Action('left'))
        
        if stateSpace.validPosition(row, col + 1):
            actions.append(Action('right'))
        return actions
    
    def nextIntendedPosition(self, row, col, action):
        if action.move == 'left':
            return (row, col - 1)
        elif action.move == 'right':
            return (row, col + 1)
        elif action.move == 'none':
            return (row, col)
        elif action.move == 'up':
            return (row - 1, col)
        elif action.move == 'down':
            return (row + 1, col)
        else:
            print("Not a valid move")
    
    def probabilityNewState(self, s, a, s0):
        if not stateSpace.validPosition(s[0], s[1]):
            return 0

        if (s[0], s[1]) not in stateSpace.getMoves(s0[0], s0[1]):
            return 0

        intendedRow, intendedCol = stateSpace.nextIntendedPosition(s0[0], s0[1], a)
        if s[0] == intendedRow and s[1] == intendedCol:
            if a.move == 'none':
                return 1.
            else:
                return 1. - p_e + p_e/4

        #If next state is a position robot was not intending to go
        elif s[0] == s0[0] and s[1] == s0[1]:
            return 0
        else:
            return p_e
    
    def valueFunction(self):
        value_fn = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
        stable = False
        while not stable:
            delta = 0
            new_value_fn = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
            for row in range(self.numRows):
                for col in range(self.numCols):
                    actions = self.getActions(row, col)
                    moves = self.getMoves(row, col)
                    bestValue = 0
                    for action in actions:
                        for move in moves:
                            rewardOfMove = self.getReward(move[0], move[1]) + gamma * value_fn[move[0]][move[1]]
                            newValue = self.probabilityNewState(move, action, (row,col)) * rewardOfMove
                            bestValue = max(bestValue, newValue)
                    new_value_fn[row][col] = bestValue
                    delta = max(delta, abs(new_value_fn[row][col] - value_fn[row][col]))

            value_fn = new_value_fn
            if delta < epsilon:
                stable = True
        return new_value_fn

# %%
class Policy:
    def __init__(self, policyMatrix):
        # PolicyFunction should take two arguments, stateSpace and state
        self.policyMatrix = policyMatrix
    
    def displayPolicy(self, stateSpace):
        display = [["" for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)]
        for row in range(stateSpace.numRows):
            for col in range(stateSpace.numCols):
                if not stateSpace.validPosition(row, col):
                    display[row][col] = 'X'
                else:
                    display[row][col] = self.policyMatrix[row][col].move
        for row in display:
            print(row)  
    
    def evaluatePolicy(self, stateSpace):
        policy_values = [[0 for x in range(len(self.policyMatrix[0]))] for x in range(len(self.policyMatrix))]
        stable = False
        while not stable:
            delta = 0
            new_policy_values = [[0 for x in range(len(self.policyMatrix[0]))] for x in range(len(self.policyMatrix))]
            
            for row in range(len(self.policyMatrix)):
                for col in range(len(self.policyMatrix[row])):
                    action = self.policyMatrix[row][col]
                    for move in stateSpace.getMoves(row, col):
                        reward = stateSpace.getReward(move[0], move[1]) + gamma * policy_values[move[0]][move[1]]
                        new_policy_values[row][col] += stateSpace.probabilityNewState(move, action, (row, col)) * reward
                    delta = max(delta, abs(new_policy_values[row][col] - policy_values[row][col]))
            
            policy_values = new_policy_values
            if delta < epsilon:
                stable = True
        return policy_values
    
    def evaluatePolicyForState(policy, stateSpace, state):
        return policy.evaluatePolicyForStateHelper(value_fn, stateSpace, state, 1, 0)

# %%
alwaysLeft = Policy([[Action('left') for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)])
stateSpace = StateSpace(L, H, [], [(0, 2, 10)])
currRewards = [[0 for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)]
for row in alwaysLeft.evaluatePolicy(stateSpace):
    print(row)
# Out:
# [0.0009221433750000002, 0.10249620168525626, 0.18394560573750002, 10.172748017261682, 9.083630949398437]
# [2.5289890875000006e-05, 0.0018874071000000003, 0.1050362466191875, 0.187325154675, 0.24911965068236716]
# [4.3740000000000004e-07, 2.6263379250000005e-05, 0.0009870426, 0.0026066403905625002, 0.0043086360375]
# [6.561000000000002e-09, 2.9160000000000004e-07, 9.4049829e-06, 2.89413e-05, 6.46295405625e-05]
# [0.0, 3.280500000000001e-09, 7.290000000000001e-08, 3.2558962500000006e-07, 0.0]
# [0.0, 0.0, 6.561000000000001e-10, 0.0, 0.0]

# %% [markdown]
# ### Question 3(d)
# Write a function that returns a matrix/array π giving the optimal policy under a one-step lookahead (Bellman
# backup) when given an input value function V . Display the policy that results from a one-step improvement
# on π0.

# %%
def oneStepPolicyMaker(policy, stateSpace):
    value_fn = policy.evaluatePolicy(stateSpace)
    new_policy = Policy([[Action('none') for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)])
    for row in range(stateSpace.numRows):
        for col in range(stateSpace.numCols):
            new_policy.policyMatrix[row][col] = bellman_backup(policy, stateSpace, (row, col), value_fn)
    return new_policy

def bellman_backup(policy, stateSpace, state, value_fn):
    """
    Returns the best action and associated expected value of that action
    """
    actions = stateSpace.getActions(state[0], state[1])
    possibilities = []
    for action in actions:
        for move in stateSpace.getMoves(state[0], state[1]):
            value = stateSpace.probabilityNewState(move, action, state) 
            value *= stateSpace.getReward(move[0], move[1]) + gamma * value_fn[move[0]][move[1]]
            possibilities.append((value, action))
    maximum = max(possibilities, key=lambda x: x[0])
    for i in range(len(possibilities)):
        if possibilities[i] == maximum:
            return possibilities[i][1]

# %%
pi_0 = Policy([[Action('left') for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)])
policy = oneStepPolicyMaker(pi_0, stateSpace)
policy.displayPolicy(stateSpace)
# Out:
# ['right', 'right', 'none', 'left', 'left']
# ['right', 'right', 'up', 'up', 'up']
# ['right', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up']
# ['none', 'up', 'up', 'up', 'none']

# %% [markdown]
# ### Question 3(e)
# Combine your functions above to create a new function that computes policy iteration on the MDP, returning
# optimal policy π with optimal value V. Display π

# %%
# def policy_fn(stateSpace, state):
    
def createOptimalPolicy(stateSpace):
    #initialize random policy
    policy = Policy([[Action('left') for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)])
    stable = False
    while not stable:
        newPolicy = oneStepPolicyMaker(policy, stateSpace)
        allSame = True
        for row in range(len(newPolicy.policyMatrix)):
            for col in range(len(newPolicy.policyMatrix[row])):
                if newPolicy.policyMatrix[row][col].move != policy.policyMatrix[row][col].move:
                    allSame = False
        stable = allSame
        policy = newPolicy
    return policy

# %%
rewards = [(3, 2, 1), (5, 2, 10), (0, 4, -100), (1, 4, -100), (2, 4, -100), (3, 4, -100), (4, 4, -100), (5, 4, -100)]
stateSpace = StateSpace(L, H, [(2,1), (2,2), (4,1), (4,2)], rewards)
createOptimalPolicy(stateSpace).displayPolicy(stateSpace)
# Out:
# ['down', 'down', 'down', 'down', 'left']
# ['down', 'left', 'right', 'down', 'left']
# ['down', 'X', 'X', 'down', 'left']
# ['down', 'right', 'right', 'down', 'left']
# ['down', 'X', 'X', 'down', 'left']
# ['right', 'right', 'none', 'left', 'left']

# %% [markdown]
# ### Question 3(f)
# How much compute time did it take to generate your optimal policy in 3(e)? You may want to use your
# programming language’s built-in runtime analysis tool.

# %%
# %time createOptimalPolicy(stateSpace).displayPolicy(stateSpace)
# Out:
# ['down', 'down', 'down', 'down', 'left']
# ['down', 'left', 'right', 'down', 'left']
# ['down', 'X', 'X', 'down', 'left']
# ['down', 'right', 'right', 'down', 'left']
# ['down', 'X', 'X', 'down', 'left']
# ['right', 'right', 'none', 'left', 'left']
# CPU times: user 185 ms, sys: 3.4 ms, total: 188 ms
# Wall time: 199 ms

# %% [markdown]
# ### Question 3(g)
# Starting in the initial state as drawn above, plot a trajectory under the optimal policy. What is the total
# discounted reward of that trajectory? What is the expected discounted sum-of-rewards for a robot starting in
# that inital state?

# %%
class Policy:
    def __init__(self, policyMatrix):
        # PolicyFunction should take two arguments, stateSpace and state
        self.policyMatrix = policyMatrix
    
    def displayPolicy(self, stateSpace):
        display = [["" for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)]
        for row in range(stateSpace.numRows):
            for col in range(stateSpace.numCols):
                if not stateSpace.validPosition(row, col):
                    display[row][col] = 'X'
                else:
                    display[row][col] = self.policyMatrix[row][col].move
        for row in display:
            print(row)  
    
    def evaluatePolicy(self, stateSpace):
        policy_values = [[0 for x in range(len(self.policyMatrix[0]))] for x in range(len(self.policyMatrix))]
        stable = False
        while not stable:
            delta = 0
            new_policy_values = [[0 for x in range(len(self.policyMatrix[0]))] for x in range(len(self.policyMatrix))]
            
            for row in range(len(self.policyMatrix)):
                for col in range(len(self.policyMatrix[row])):
                    action = self.policyMatrix[row][col]
                    for move in stateSpace.getMoves(row, col):
                        reward = stateSpace.getReward(move[0], move[1]) + gamma * policy_values[move[0]][move[1]]
                        new_policy_values[row][col] += stateSpace.probabilityNewState(move, action, (row, col)) * reward
                    delta = max(delta, abs(new_policy_values[row][col] - policy_values[row][col]))
            
            policy_values = new_policy_values
            if delta < epsilon:
                stable = True
        return policy_values
    
    def evaluatePolicyForState(policy, stateSpace, state):
        return policy.evaluatePolicyForStateHelper(value_fn, stateSpace, state, 1, 0)

    def getPathAndRewardFrom(self, row, col, stateSpace):
        """
        Retruns the path and the reward from the row and col
        """
        trajectory = [['.' for x in range(stateSpace.numCols)] for x in range(stateSpace.numRows)]
        if self.policyMatrix[row][col].move == 'none':
            return stateSpace.getReward(row, col)
        total_reward, iteration, expected_reward = 0, 0, 0
        path = []
        delta = epsilon
        while True:
            trajectory[row][col] = '*'
            delta = pow(gamma, iteration) * stateSpace.getReward(row, col)
            path.append(policy.policyMatrix[row][col].move)
            total_reward += delta
            nextRow, nextCol = stateSpace.nextIntendedPosition(row, col, policy.policyMatrix[row][col])
            expected_reward += delta * stateSpace.probabilityNewState((nextRow, nextCol), policy.policyMatrix[row][col], (row, col))
            if self.policyMatrix[row][col].move == 'none':
                break
            row, col = stateSpace.nextIntendedPosition(row, col, policy.policyMatrix[row][col])
            iteration += 1
        return path, trajectory, total_reward, expected_reward

# %%
policy = createOptimalPolicy(stateSpace)
path, trajectory, total_reward, expected_reward = policy.getPathAndRewardFrom(0, 2, stateSpace)
for row in trajectory:
    print(row)
print(f'Total Reward = {total_reward}')
print(f'Expected Reward = {expected_reward}')
# Out:
# ['.', '.', '*', '.', '.']
# ['.', '.', '*', '*', '.']
# ['.', '.', '.', '*', '.']
# ['.', '.', '.', '*', '.']
# ['.', '.', '.', '*', '.']
# ['.', '.', '*', '*', '.']
# Total Reward = 4.7829690000000005
# Expected Reward = 4.7829690000000005

# %% [markdown]
# ### Question 4a
# Using an initial condition V (s) = 0 ∀s ∈ S, write a function (and any necessary subfunctions, perhaps derived
# from the functions above) to compute value iteration, again returning optimal policy π with optimal value V

# %%
value_fn = stateSpace.valueFunction()
for row in value_fn:
    print(row)
# Out:
# [50.33449405464303, 44.95319413639661, 50.33449405464303, 56.358967686866734, 50.33449405464303]
# [56.358967686866734, 50.33449405464303, 56.358967686866734, 63.103479579483555, 56.358967686866734]
# [63.103479579483555, 57.245518311866725, 64.09597957948355, 70.65408016619963, 63.103479579483555]
# [70.65408016619963, 64.09597957948355, 70.65408016619963, 79.1071035497013, 70.65408016619963]
# [79.1071035497013, 88.57039647639931, 99.16469418277008, 88.57039647639931, 79.1071035497013]
# [88.57039647639931, 99.16469418277008, 99.9140495544283, 99.16469418277008, 88.57039647639931]

# %% [markdown]
# ### Question 4b
# Run this function to recompute and display the optimal policy π Also generate a trajectory for a robot and
# compute its reward as described in 3(g). Compare these results with those you got from policy iteration.

# %%
class StateSpace:
    """
    State is a H by L grid where a 0 represents an open space and a 1 represents an obstacle
    ObstacleList should be a list of tuples where each tuple is (row, col) of the obstacle
    RewardList should be a three tuple (row, col, rewardValue)
    """
    def __init__(self, L, H, obstacleList = [], rewardList = []):
        self.numRows = H
        self.numCols = L
        self.stateSpace = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
        for obstacle in obstacleList:
            self.stateSpace[obstacle[0]][obstacle[1]] = -1
        self.rewardMap = {}
        for reward in rewardList:
            self.rewardMap[(reward[0], reward[1])] = reward[2]
    def validPosition(self, row, col):
        if row < 0 or col < 0 or row >= self.numRows or col >= self.numCols:
            return False
        #2a
        if self.stateSpace[row][col] == -1:
            return False
        return True
    
    #2b
    def getReward(self, row, col):
        if (row, col) in self.rewardMap:
            return self.rewardMap[(row, col)]
        else:
            return 0
    
    def getMoves(self, row, col):
        moves = [(row, col)]
        if stateSpace.validPosition(row - 1, col):
            moves.append((row - 1, col))
        
        if stateSpace.validPosition(row + 1, col):
            moves.append((row + 1, col))
        
        if stateSpace.validPosition(row, col - 1):
            moves.append((row, col - 1))
        
        if stateSpace.validPosition(row, col + 1):
            moves.append((row, col + 1))
        return moves
    
    def getActions(self, row, col):
        actions = [Action('none')]
        if stateSpace.validPosition(row - 1, col):
            actions.append(Action('up'))
        
        if stateSpace.validPosition(row + 1, col):
            actions.append(Action('down'))
        
        if stateSpace.validPosition(row, col - 1):
            actions.append(Action('left'))
        
        if stateSpace.validPosition(row, col + 1):
            actions.append(Action('right'))
        return actions
    
    def nextIntendedPosition(self, row, col, action):
        if action.move == 'left':
            return (row, col - 1)
        elif action.move == 'right':
            return (row, col + 1)
        elif action.move == 'none':
            return (row, col)
        elif action.move == 'up':
            return (row - 1, col)
        elif action.move == 'down':
            return (row + 1, col)
        else:
            print("Not a valid move")
    
    def probabilityNewState(self, s, a, s0):
        if not stateSpace.validPosition(s[0], s[1]):
            return 0

        if (s[0], s[1]) not in stateSpace.getMoves(s0[0], s0[1]):
            return 0

        intendedRow, intendedCol = stateSpace.nextIntendedPosition(s0[0], s0[1], a)
        if s[0] == intendedRow and s[1] == intendedCol:
            if a.move == 'none':
                return 1.
            else:
                return 1. - p_e + p_e/4

        #If next state is a position robot was not intending to go
        elif s[0] == s0[0] and s[1] == s0[1]:
            return 0
        else:
            return p_e
    
    def valueFunction(self):
        value_fn = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
        stable = False
        currPolicy = Policy([[Action('none') for x in range(self.numCols)] for x in range(self.numRows)])
        while not stable:
            delta = 0
            new_value_fn = [[0 for x in range(self.numCols)] for x in range(self.numRows)]
            for row in range(self.numRows):
                for col in range(self.numCols):
                    actions = self.getActions(row, col)
                    moves = self.getMoves(row, col)
                    bestValue = 0
                    for action in actions:
                        for move in moves:
                            rewardOfMove = self.getReward(move[0], move[1]) + gamma * value_fn[move[0]][move[1]]
                            newValue = self.probabilityNewState(move, action, (row,col)) * rewardOfMove
                            if newValue > bestValue:
                                bestValue = newValue
                                currPolicy.policyMatrix[row][col] = action
                    new_value_fn[row][col] = bestValue
                    delta = max(delta, abs(new_value_fn[row][col] - value_fn[row][col]))

            value_fn = new_value_fn
            if delta < epsilon:
                stable = True
        return (new_value_fn, currPolicy)

# %%
stateSpace = StateSpace(L, H, [(2,1), (2,2), (4,1), (4,2)], rewards)
value_fn, policy = stateSpace.valueFunction()
policy.displayPolicy(stateSpace)
# Out:
# ['down', 'down', 'down', 'down', 'left']
# ['down', 'left', 'right', 'down', 'left']
# ['down', 'X', 'X', 'down', 'left']
# ['down', 'right', 'right', 'down', 'left']
# ['down', 'X', 'X', 'down', 'left']
# ['right', 'right', 'none', 'left', 'left']

# %% [markdown]
# ### Question 4(b).  cont'd

# %%
path, trajectory, total_reward, expected_reward = policy.getPathAndRewardFrom(0, 2, stateSpace)
for row in trajectory:
    print(row)
print(f'Total Reward = {total_reward}')
print(f'Expected Reward = {expected_reward}')
# Out:
# ['.', '.', '*', '.', '.']
# ['.', '.', '*', '*', '.']
# ['.', '.', '.', '*', '.']
# ['.', '.', '.', '*', '.']
# ['.', '.', '.', '*', '.']
# ['.', '.', '*', '*', '.']
# Total Reward = 4.7829690000000005
# Expected Reward = 4.7829690000000005

# %% [markdown]
# ### Qeustion 4(c).
# How much compute time did it take to generate your results from 4(b)? Use the same timing method as in
# 3(f).

# %%
# %time _, __ = stateSpace.valueFunction()
# Out:
# CPU times: user 126 ms, sys: 2.77 ms, total: 129 ms
# Wall time: 132 ms

# %% [markdown]
# ### Question 5(a).
# Explore different values of γ, pe to find different optimal policies, and characterize / explain your observations.
#
# (Note the output gets cut off in the pdf but if you run the ipynb you will be able to see it all)

# %%
gamma = 0.96
gammas = [0.5, 0.7, 0.96]
p_es = [0.01, 0.06, 0.1, 0.2]
rewards = [(3, 2, 10), (5, 2, 100), (0, 4, -100), (1, 4, -100), (2, 4, -100), \
           (10, 11, 200), (11, 4, 200), (14, 14, -100), (8, 8, 32), (18, 18, 150), \
           (16, 3, 44), (15, 15, 100), (0, 9, 280), (1, 18, 200), (1, 19, 250)]
stateSpace = StateSpace(20, 20, [(2,1), (2,2), (4,1), (4,4)], rewards)
for g in gammas:
    for p in p_es:
        gamma = g
        p_e = p
        
        value_fn, policy = stateSpace.valueFunction()
        path, trajectory, total_reward, expected_reward = policy.getPathAndRewardFrom(2, 0, stateSpace)
        
        print(f'Gamma = {gamma}')
        print(f'p_e = {p_e}')
        policy.displayPolicy(stateSpace)
        for row in trajectory:
            print(row)
        print(f'Total Reward = {total_reward}')
        print(f'Expected Reward = {expected_reward}')
# Out:
# Gamma = 0.5
# p_e = 0.01
# ['down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['down', 'left', 'right', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'up', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'right', 'right', 'none', 'left', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'left']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'right', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 4.375
# Expected Reward = 4.365625
# Gamma = 0.5
# p_e = 0.06
# ['down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['down', 'left', 'right', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'right', 'right', 'none', 'left', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'left']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'right', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 4.375
# Expected Reward = 4.31875
# Gamma = 0.5
# p_e = 0.1
# ['down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['down', 'left', 'right', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'right', 'right', 'none', 'left', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'left']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'right', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 4.375
# Expected Reward = 4.28125
# Gamma = 0.5
# p_e = 0.2
# ['down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['down', 'left', 'right', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'right', 'right', 'none', 'left', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'left']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'right', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 4.375
# Expected Reward = 4.1875
# Gamma = 0.7
# p_e = 0.01
# ['down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['down', 'left', 'right', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'down', 'right', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'left']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'none', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 20.236999999999995
# Expected Reward = 20.211274999999993
# Gamma = 0.7
# p_e = 0.06
# ['down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['down', 'left', 'right', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'down', 'right', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'left']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 20.236999999999995
# Expected Reward = 20.082649999999994
# Gamma = 0.7
# p_e = 0.1
# ['down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['down', 'left', 'right', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'up', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'down', 'right', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'left']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 20.236999999999995
# Expected Reward = 19.979749999999996
# Gamma = 0.7
# p_e = 0.2
# ['down', 'down', 'down', 'down', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['down', 'left', 'right', 'down', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'up', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'down', 'right', 'none', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'left']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 20.236999999999995
# Expected Reward = 19.722499999999997
# Gamma = 0.96
# p_e = 0.01
# ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'none']
# ['up', 'X', 'X', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'right', 'right', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'X', 'up', 'up', 'X', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'up', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'up']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'left', 'up', 'left', 'down', 'down', 'up']
# ['right', 'right', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 100.43123358491543
# Expected Reward = 101.01830192718744
# Gamma = 0.96
# p_e = 0.06
# ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['up', 'X', 'X', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'right', 'right', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'X', 'up', 'up', 'X', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'up']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'left', 'none', 'down', 'down', 'down', 'down']
# ['right', 'right', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 100.43123358491543
# Expected Reward = 103.95364363854743
# Gamma = 0.96
# p_e = 0.1
# ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['up', 'X', 'X', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'right', 'right', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'up', 'X', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'up']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'none', 'left', 'down', 'down', 'down']
# ['right', 'right', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 100.43123358491543
# Expected Reward = 106.30191700763542
# Gamma = 0.96
# p_e = 0.2
# ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'none']
# ['down', 'X', 'X', 'up', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'down', 'left', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['down', 'X', 'down', 'down', 'X', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'up', 'up']
# ['down', 'down', 'down', 'down', 'down', 'down', 'down', 'down', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'left', 'left', 'left', 'left', 'up']
# ['right', 'right', 'right', 'right', 'none', 'left', 'left', 'left', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'none', 'left', 'left', 'down', 'down']
# ['right', 'right', 'right', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'down']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'right', 'right', 'right', 'right', 'right', 'right', 'none', 'left']
# ['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['*', '*', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '*', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# Total Reward = 90.38462975999998
# Expected Reward = 89.05752575999999

# %% [markdown]
# ### Observations
# 1.
